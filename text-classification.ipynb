# %%
import pandas as pd

# %%
books = pd.read_csv('books_cleaned.csv')

# %%
books['categories'].value_counts().reset_index()
# Out:
#                     categories  count
# 0                      Fiction   2111
# 1             Juvenile Fiction    390
# 2    Biography & Autobiography    311
# 3                      History    207
# 4           Literary Criticism    124
# ..                         ...    ...
# 474               Conspiracies      1
# 475       Brothers and sisters      1
# 476             Rock musicians      1
# 477             Community life      1
# 478    Indic fiction (English)      1
#
# [479 rows x 2 columns]

# %% [markdown]
# there is a bias in type of books

# %%
category_mapping = {'Fiction' : "Fiction",
 'Juvenile Fiction': "Children's Fiction",
 'Biography & Autobiography': "Nonfiction",
 'History': "Nonfiction",
 'Literary Criticism': "Nonfiction",
 'Philosophy': "Nonfiction",
 'Religion': "Nonfiction",
 'Comics & Graphic Novels': "Fiction",
 'Drama': "Fiction",
 'Juvenile Nonfiction': "Children's Nonfiction",
 'Science': "Nonfiction",
 'Poetry': "Fiction"}

books["simple_categories"] = books["categories"].map(category_mapping)

# %%
books.value_counts().reset_index()
# Out:
#              isbn13      isbn10                           title  \
# 0     9780002005883  0002005883                          Gilead
# 1     9780743457910  0743457919        The Honourable Schoolboy
# 2     9780743292498  0743292499                       True Evil
# 3     9780743296168  0743296168                  The Good House
# 4     9780743297318  0743297318            Look Homeward, Angel
# ...             ...         ...                             ...
# 3636  9780380710843  0380710846                  Caesar's Women
# 3637  9780380720446  0380720442                Wrinkles in Time
# 3638  9780380720866  0380720868          Shadow of a Dark Queen
# 3639  9780380725786  0380725789  The Death of an Irish Sea Wolf
# 3640  9789027712059  9027712050        The Berlin Phenomenology
#
#                             authors categories  \
# 0                Marilynne Robinson    Fiction
# 1                     John le Carre    Fiction
# 2                         Greg Iles    Fiction
# 3                    Tananarive Due    Fiction
# 4                      Thomas Wolfe    Fiction
# ...                             ...        ...
# 3636             Colleen McCullough    Fiction
# 3637     George Smoot;Keay Davidson    Science
# 3638               Raymond E. Feist    Fiction
# 3639               Bartholomew Gill    Fiction
# 3640  Georg Wilhelm Friedrich Hegel    History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=91LDl...
# 2     http://books.google.com/books/content?id=BDksx...
# 3     http://books.google.com/books/content?id=62tLn...
# 4     http://books.google.com/books/content?id=koSYQ...
# ...                                                 ...
# 3636  http://books.google.com/books/content?id=yFK8F...
# 3637  http://books.google.com/books/content?id=DSv0H...
# 3638  http://books.google.com/books/content?id=j5Yyl...
# 3639  http://books.google.com/books/content?id=_-poq...
# 3640  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     Trying to rebuild his espionage organization a...          2002.0
# 2     The idyllic life of busy Natchez doctor Chris ...          2006.0
# 3     Award-winning author Tananarive Due's spine-wi...          2006.0
# 4     A Southern family with a great appetite for li...          2006.0
# ...                                                 ...             ...
# 3636  The fourth novel of the Masters of Rome series...          1997.0
# 3637  Behold the Handwriting of God Astrophysicist a...          1994.0
# 3638  A dread darkness is descending upon a great la...          1995.0
# 3639  In a remote community off the west coast of Ir...          1997.0
# 3640  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.95      589.0        11083.0
# 2               4.08      512.0        12524.0
# 3               3.93      597.0         2385.0
# 4               3.94      644.0        10780.0
# ...              ...        ...            ...
# 3636            4.24      943.0         5277.0
# 3637            3.99      360.0          985.0
# 3638            4.04      497.0        22935.0
# 3639            3.74      304.0          130.0
# 3640            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                              The Honourable Schoolboy
# 2                                             True Evil
# 3                                        The Good House
# 4                                  Look Homeward, Angel
# ...                                                 ...
# 3636                                     Caesar's Women
# 3637                                   Wrinkles in Time
# 3638  Shadow of a Dark Queen: Book One of the Serpen...
# 3639                     The Death of an Irish Sea Wolf
# 3640                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories  \
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780743457910 Trying to rebuild his espionage ...           Fiction
# 2     9780743292498 The idyllic life of busy Natchez...           Fiction
# 3     9780743296168 Award-winning author Tananarive ...           Fiction
# 4     9780743297318 A Southern family with a great a...           Fiction
# ...                                                 ...               ...
# 3636  9780380710843 The fourth novel of the Masters ...           Fiction
# 3637  9780380720446 Behold the Handwriting of God As...        Nonfiction
# 3638  9780380720866 A dread darkness is descending u...           Fiction
# 3639  9780380725786 In a remote community off the we...           Fiction
# 3640  9789027712059 Since the three volume edition o...        Nonfiction
#
#       count
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 3636      1
# 3637      1
# 3638      1
# 3639      1
# 3640      1
#
# [3641 rows x 15 columns]

# %%
books[(books["simple_categories"].isna())]
# Out:
#              isbn13      isbn10  \
# 1     9780002261982  0002261987
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# 5     9780006380832  0006380832
# 6     9780006470229  000647022X
# ...             ...         ...
# 5190  9788125026600  8125026606
# 5191  9788171565641  8171565646
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
#
#                                                   title  \
# 1                                          Spider's Web
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# 5                                Empires of the Monsoon
# 6                                  The Gap Into Madness
# ...                                                 ...
# 5190                            Nietzsche For Beginners
# 5191                               Aspects of the Novel
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
#
#                               authors                           categories  \
# 1     Charles Osborne;Agatha Christie        Detective and mystery stories
# 3                 Clive Staples Lewis                       Christian life
# 4                 Clive Staples Lewis                       Christian life
# 5                        Richard Hall                         Africa, East
# 6                Stephen R. Donaldson  Hyland, Morn (Fictitious character)
# ...                               ...                                  ...
# 5190                      Marc Sautet                                  NaN
# 5191                    E. M. Forster                      English fiction
# 5192                 Nayantara Sahgal              Indic fiction (English)
# 5193                    Hermann Hesse                    Adventure stories
# 5194                     Robin Sharma                     Health & Fitness
#
#                                               thumbnail  \
# 1     http://books.google.com/books/content?id=gA5GP...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# 5     http://books.google.com/books/content?id=MuPEQ...
# 6     http://books.google.com/books/content?id=4oXav...
# ...                                                 ...
# 5190  http://books.google.com/books/content?id=fPIv8...
# 5191  http://books.google.com/books/content?id=qWU9P...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
#
#                                             description  published_year  \
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# 5     Until Vasco da Gama discovered the sea-route t...          1998.0
# 6     A new-cover reissue of the fourth book in the ...          1994.0
# ...                                                 ...             ...
# 5190  Not only does Nietzsche for Beginners delve in...          2004.0
# 5191  Forster's lively, informed originality and wit...          2004.0
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
#
#       average_rating  num_pages  ratings_count  \
# 1               3.83      241.0         5164.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# 5               4.41      608.0           65.0
# 6               4.15      743.0          103.0
# ...              ...        ...            ...
# 5190            3.26      192.0           21.0
# 5191            3.83      141.0           10.0
# 5192            2.93      324.0            0.0
# 5193            3.70      175.0           24.0
# 5194            3.82      198.0         1568.0
#
#                                      title_and_subtitle  \
# 1                                 Spider's Web: A Novel
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# 5     Empires of the Monsoon: A History of the India...
# 6                 The Gap Into Madness: Chaos and Order
# ...                                                 ...
# 5190                            Nietzsche For Beginners
# 5191                               Aspects of the Novel
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
#
#                                      tagged_description simple_categories
# 1     9780002261982 A new 'Christie for Christmas' -...               NaN
# 3     9780006280897 Lewis' work on the nature of lov...               NaN
# 4     9780006280934 "In The Problem of Pain, C.S. Le...               NaN
# 5     9780006380832 Until Vasco da Gama discovered t...               NaN
# 6     9780006470229 A new-cover reissue of the fourt...               NaN
# ...                                                 ...               ...
# 5190  9788125026600 Not only does Nietzsche for Begi...               NaN
# 5191  9788171565641 Forster's lively, informed origi...               NaN
# 5192  9788172235222 On A Train Journey Home To North...               NaN
# 5193  9788173031014 This book tells the tale of a ma...               NaN
# 5194  9788179921623 Wisdom to Create a Life of Passi...               NaN
#
# [1454 rows x 14 columns]

# %%
from transformers import pipeline

fiction_categories = ["Fiction", "Nonfiction"]

pipe = pipeline("zero-shot-classification",
                model="facebook/bart-large-mnli",
                device=0)  # Use 0 for GPU (if available)
# Out:
# Device set to use cuda:0

# %%
sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[0]

# %%
pipe(sequence, fiction_categories)
# Out:
# {'sequence': 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.',
#  'labels': ['Fiction', 'Nonfiction'],
#  'scores': [0.8438268899917603, 0.15617309510707855]}

# %%
import numpy as np
max_index = np.argmax(pipe(sequence, fiction_categories)["scores"])
max_label = pipe(sequence, fiction_categories)["labels"][max_index]
max_label
# Out:
# 'Fiction'

# %%
books['simple_categories'].unique()
# Out:
# array(['Fiction', nan, "Children's Fiction", 'Nonfiction',
#        "Children's Nonfiction"], dtype=object)

# %%
def generate_predictions(sequence, category):
    predictions = pipe(sequence, category)
    max_index = np.argmax(predictions["scores"])
    max_label = predictions["labels"][max_index]
    return max_label

# %% [markdown]
# Now i will check my models accuracy before actually using it

# %%
actual_cat = []
predicted_cat = []

# %%
from tqdm import tqdm

actual_cats = []
predicted_cats = []

for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Fiction"]
# Out:
# 100%|██████████| 300/300 [00:26<00:00, 11.45it/s]

# %%
for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Nonfiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Nonfiction"]
# Out:
# 100%|██████████| 300/300 [00:28<00:00, 10.60it/s]

# %%
predictions_df = pd.DataFrame({"actual_categories": actual_cats, "predicted_categories": predicted_cats})

# %%
predictions_df["correct_prediction"] = (
    np.where(predictions_df["actual_categories"] == predictions_df["predicted_categories"], 1, 0)
)

# %%
predictions_df["correct_prediction"].sum() / len(predictions_df)
# Out:
# 0.7783333333333333

# %%
isbns = []
predicted_cats = []

missing_cats = books.loc[books["simple_categories"].isna(), ["isbn13", "description"]].reset_index(drop=True)

# %%
missing_cats
# Out:
#              isbn13                                        description
# 0     9780002261982  A new 'Christie for Christmas' -- a full-lengt...
# 1     9780006280897  Lewis' work on the nature of love divides love...
# 2     9780006280934  "In The Problem of Pain, C.S. Lewis, one of th...
# 3     9780006380832  Until Vasco da Gama discovered the sea-route t...
# 4     9780006470229  A new-cover reissue of the fourth book in the ...
# ...             ...                                                ...
# 1449  9788125026600  Not only does Nietzsche for Beginners delve in...
# 1450  9788171565641  Forster's lively, informed originality and wit...
# 1451  9788172235222  On A Train Journey Home To North India After L...
# 1452  9788173031014  This book tells the tale of a man who goes on ...
# 1453  9788179921623  Wisdom to Create a Life of Passion, Purpose, a...
#
# [1454 rows x 2 columns]

# %%
for i in tqdm(range(0, len(missing_cats))):
    sequence = missing_cats["description"][i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    isbns += [missing_cats["isbn13"][i]]
# Out:
# 100%|██████████| 1454/1454 [02:13<00:00, 10.93it/s]

# %%
missing_predicted_df = pd.DataFrame({"isbn13": isbns, "predicted_categories": predicted_cats})

# %%
missing_predicted_df.head()
# Out:
#           isbn13 predicted_categories
# 0  9780002261982              Fiction
# 1  9780006280897           Nonfiction
# 2  9780006280934           Nonfiction
# 3  9780006380832           Nonfiction
# 4  9780006470229              Fiction

# %%
books = pd.merge(books, missing_predicted_df, on="isbn13", how="left")
books["simple_categories"] = np.where(books["simple_categories"].isna(), books["predicted_categories"], books["simple_categories"])
books = books.drop(columns = ["predicted_categories"])

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5192            2.93      324.0            0.0
# 5193            3.70      175.0           24.0
# 5194            3.82      198.0         1568.0
# 5195            4.51      531.0          104.0
# 5196            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...        Nonfiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...        Nonfiction
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...           Fiction
# 5193  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5194  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
# [5197 rows x 14 columns]

# %%
books[books["categories"].str.lower().isin([
    "romance",
    "science fiction",
    "scifi",
    "fantasy",
    "horror",
    "mystery",
    "thriller",
    "comedy",
    "crime",
    "historical"
])]
# Out:
#              isbn13      isbn10                                     title  \
# 24    9780006513087  0006513085                                   Gravity
# 475   9780099410355  0099410354                                   Traitor
# 478   9780099422341  0099422344                            Yeats is Dead!
# 491   9780099446729  0099446723                            Blackwood Farm
# 1090  9780261102422  0261102427                          The Silmarillion
# 1435  9780340837955  0340837950                Stranger in a Strange Land
# 1439  9780345251220  0345251229                      Visions from Nowhere
# 2845  9780575075597  0575075597                                    Replay
# 2860  9780590254762  0590254766      The lion, the witch and the wardrobe
# 3288  9780739423851  0739423851                           Wizard's Castle
# 3289  9780739439708  0739439707                              Time Quartet
# 3563  9780760728505  076072850X              20,000 Leagues Under the Sea
# 4483  9781416502043  1416502041  The Voyage of the Jerle Shannara Trilogy
# 4979  9781841494081  1841494089            The Darkness that Comes Before
# 5040  9781857231359  185723135X                            Use of Weapons
# 5057  9781857989342  1857989341                       The Gods Themselves
#
#                         authors       categories  \
# 24               Tess Gerritsen  Science fiction
# 475     Matthew Woodring Stover  Science fiction
# 478             Joseph O'Connor           Comedy
# 491                   Anne Rice           Horror
# 1090  John Ronald Reuel Tolkien          Fantasy
# 1435         Robert A. Heinlein  Science fiction
# 1439              William Arrow  Science fiction
# 2845               Ken Grimwood          Fantasy
# 2860        Clive Staples Lewis          Fantasy
# 3288          Diana Wynne Jones          Fantasy
# 3289          Madeleine L'Engle  Science fiction
# 3563                Jules Verne  Science fiction
# 4483               Terry Brooks          Fantasy
# 4979            R. Scott Bakker          Fantasy
# 5040                 Iain Banks  Science fiction
# 5057               Isaac Asimov  Science fiction
#
#                                               thumbnail  \
# 24    http://books.google.com/books/content?id=KI66c...
# 475   http://books.google.com/books/content?id=VbICO...
# 478   http://books.google.com/books/content?id=DrE3I...
# 491   http://books.google.com/books/content?id=cIn8T...
# 1090  http://books.google.com/books/content?id=22ePu...
# 1435  http://books.google.com/books/content?id=ZQhiP...
# 1439                                                NaN
# 2845  http://books.google.com/books/content?id=9vmNP...
# 2860                                                NaN
# 3288  http://books.google.com/books/content?id=hB7hA...
# 3289                                                NaN
# 3563                                                NaN
# 4483  http://books.google.com/books/content?id=jqVsA...
# 4979  http://books.google.com/books/content?id=BG8qG...
# 5040                                                NaN
# 5057  http://books.google.com/books/content?id=8ClIP...
#
#                                             description  published_year  \
# 24    Emma Watson a research physician has been trai...          2004.0
# 475   From the depths of catastrophe, a glimmer of h...          2002.0
# 478   In aid of Amnesty International, this is a bri...          2002.0
# 491   Lestat Is Back, Saviour And Demon, Presiding O...          2003.0
# 1090  Tolkien's Silmarillion is the core work of the...          1999.0
# 1435  Epic, entertaining, Stranger in a Strange Land...          2005.0
# 1439  The first novel in the series, "Return to the ...          1976.0
# 2845  At forty-three Jeff Winston is tired of his lo...          2005.0
# 2860  Four English school children enter the magic l...          1995.0
# 3288  Howl's moving castle - Eldest of three sisters...          2002.0
# 3289  Blending magic with quantum physics, Madeleine...          2003.0
# 3563  Retells the adventures of a French professor a...          2002.0
# 4483  When the body of a half-drowned elf is found f...          2004.0
# 4979  A score of centuries has passed since the Firs...          2005.0
# 5040  The man known as Cheradenine Zakalwe was one o...          1992.0
# 5057  In the year 2100, mankind on Earth, settlers i...          2000.0
#
#       average_rating  num_pages  ratings_count  \
# 24              4.04      342.0         8024.0
# 475             4.00      320.0         6765.0
# 478             3.39      298.0           34.0
# 491             3.86      774.0        26145.0
# 1090            3.91      384.0          253.0
# 1435            3.92      672.0          563.0
# 1439            3.23      183.0           10.0
# 2845            4.16      272.0          412.0
# 2860            4.21      189.0          860.0
# 3288            4.44      376.0          439.0
# 3289            4.35      646.0          165.0
# 3563            3.88      394.0       135778.0
# 4483            4.26     1260.0           84.0
# 4979            3.79      638.0          317.0
# 5040            4.19      411.0        30779.0
# 5057            4.09      288.0        41304.0
#
#                                     title_and_subtitle  \
# 24                                             Gravity
# 475                                            Traitor
# 478   Yeats is Dead!: A Novel by Fifteen Irish Writers
# 491                                     Blackwood Farm
# 1090                                  The Silmarillion
# 1435                        Stranger in a Strange Land
# 1439                              Visions from Nowhere
# 2845                                            Replay
# 2860              The lion, the witch and the wardrobe
# 3288                                   Wizard's Castle
# 3289                                      Time Quartet
# 3563                      20,000 Leagues Under the Sea
# 4483          The Voyage of the Jerle Shannara Trilogy
# 4979                    The Darkness that Comes Before
# 5040                                    Use of Weapons
# 5057                               The Gods Themselves
#
#                                      tagged_description simple_categories
# 24    9780006513087 Emma Watson a research physician...        Nonfiction
# 475   9780099410355 From the depths of catastrophe, ...           Fiction
# 478   9780099422341 In aid of Amnesty International,...           Fiction
# 491   9780099446729 Lestat Is Back, Saviour And Demo...           Fiction
# 1090  9780261102422 Tolkien's Silmarillion is the co...           Fiction
# 1435  9780340837955 Epic, entertaining, Stranger in ...           Fiction
# 1439  9780345251220 The first novel in the series, "...           Fiction
# 2845  9780575075597 At forty-three Jeff Winston is t...           Fiction
# 2860  9780590254762 Four English school children ent...        Nonfiction
# 3288  9780739423851 Howl's moving castle - Eldest of...           Fiction
# 3289  9780739439708 Blending magic with quantum phys...           Fiction
# 3563  9780760728505 Retells the adventures of a Fren...           Fiction
# 4483  9781416502043 When the body of a half-drowned ...           Fiction
# 4979  9781841494081 A score of centuries has passed ...        Nonfiction
# 5040  9781857231359 The man known as Cheradenine Zak...        Nonfiction
# 5057  9781857989342 In the year 2100, mankind on Ear...           Fiction

# %%
books.to_csv("books_with_categories.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 books.to_csv("books_with_categories.csv", index=False)
#
# NameError: name 'books' is not defined

# %%
import torch
import torchvision

print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
print("Torch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
# Out:
# CUDA available: True
# GPU: NVIDIA GeForce RTX 2060
# Torch version: 2.7.1+cu118
# Torchvision version: 0.22.1+cu118
